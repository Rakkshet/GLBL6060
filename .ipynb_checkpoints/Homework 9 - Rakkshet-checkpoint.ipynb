# %% [markdown]
# ## HW9 Digit Classification with KNN and Final Project Updates

# %% [markdown]
# In this project, you'll implement your own image recognition system for classifying digits. Read through the code and the instructions carefully and add your own code where indicated.
#
# If you're interested, check out these links related to digit recognition:
#
# Yann Lecun's MNIST benchmarks: http://yann.lecun.com/exdb/mnist/
#
# Stanford Streetview research and data: http://ufldl.stanford.edu/housenumbers/

# %%
# !pip install --force-reinstall numpy matplotlib scikit-learn scipy
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# ...
#   Using cached scipy-1.13.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (60 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 3.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 8.6 MB/s eta 0:00:00:00:0100:01
# Using cached scipy-1.13.0-cp311-cp311-macosx_10_9_x86_64.whl (39.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 3.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 3.1 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install aiofiles datasets FuzzyTM
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.4 MB/s eta 0:00:00
# ...
#   Created wheel for fst-pso: filename=fst_pso-1.8.1-py3-none-any.whl size=20430 sha256=0e539e16fa7f4ddca9cfa6ad8a88d85375d9ce1fc5699a27eccb98e20520bb1f
#   Stored in directory: /Users/rakkshetsinghaal/Library/Caches/pip/wheels/69/f5/e5/18ad53fe1ed6b2af9fad05ec052e4acbac8e92441df44bad2e
# ...
#   Created wheel for miniful: filename=miniful-0.0.6-py3-none-any.whl size=3507 sha256=4f456599e10b7cf6c8967a36862a0d5e8c6bb60a682d992a8cd59b31dedebaa8
# ...

# %%
# !pip install "packaging<24.0,>=23.2"
# Out:
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.22.0 requires altair<5,>=3.2.0, but you have altair 5.2.0 which is incompatible.
# ...

# %%
# !pip install "altair<5"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 3.8 MB/s eta 0:00:0000:0100:01m
# ...
#   Attempting uninstall: altair
#     Found existing installation: altair 5.2.0
#     Uninstalling altair-5.2.0:
#       Successfully uninstalled altair-5.2.0
# ...

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# %%
# Import a bunch of libraries.
import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_openml

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

from scipy.io import arff

# %%
# Load ARFF file
mnist, meta = arff.loadarff('/Users/rakkshetsinghaal/Desktop/Yale University/GLBL 6060/GLBL6060/Homework 9 - Rakkshet/mnist_784.arff')

# %%
from sklearn.metrics import classification_report

# %%
# Set the randomizer seed so results are the same each time.
np.random.seed(0)

# %% [markdown]
# Load the data. Notice that we are splitting the data into training, development, and test. We also have a small subset of the training data called mini_train_data and mini_train_labels that you should use in all the experiments below, unless otherwise noted.

# %%
# Load the digit data either from mldata.org, or once downloaded to data_home, from disk. The data is about 53MB so this cell
# should take a while the first time your run it.
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, cache=True)

X, Y = mnist.data, mnist.target

# Rescale grayscale values to [0,1].
X = X / 255.0

# Shuffle the input: create a random permutation of the integers between 0 and the number of data points and apply this
# permutation to X and Y.
# NOTE: Each time you run this cell, you'll re-shuffle the data, resulting in a different ordering.
X = X.to_numpy()
Y = Y.to_numpy()

shuffle = np.random.permutation(np.arange(X.shape[0]))
X, Y = X[shuffle], Y[shuffle]

print('data shape:', X.shape)
print('label shape:', Y.shape)

# Set some variables to hold test, dev, and training data.
test_data, test_labels = X[61000:], Y[61000:]
dev_data, dev_labels = X[60000:61000], Y[60000:61000]
train_data, train_labels = X[:60000], Y[:60000]
mini_train_data, mini_train_labels = X[:1000], Y[:1000]
# Out:
# data shape: (70000, 784)
# label shape: (70000,)

# %%
print(type(X))
print(type(Y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# (1) Create a 10x10 grid to visualize 10 examples of each digit. Python hints:
#
# - plt.rc() for setting the colormap, for example to black and white
# - plt.subplot() for creating subplots
# - plt.imshow() for rendering a matrix
# - np.array.reshape() for reshaping a 1D feature vector into a 2D matrix (for rendering)

# %%
# Colormap to grayscale and turn off axis for cleaner visualization
plt.rc('image', cmap='gray')
plt.rc('grid', linewidth=0)
plt.rc('xtick', top=False, bottom=False, labelsize='large')
plt.rc('ytick', left=False, right=False, labelsize='large')
plt.rc('axes', facecolor='F8F8F8', edgecolor='F8F8F8')

fig, ax = plt.subplots(nrows=10, ncols=10, figsize=(15, 15))

# Hold 10 examples of each digit
examples_per_digit = 10

# 10x10 grid of subplots
for digit in range(10):
    indices = np.where(Y == str(digit))[0][:examples_per_digit] 
    for i, idx in enumerate(indices):
        ax[digit, i].imshow(X[idx].reshape(28, 28), aspect='auto') 
        ax[digit, i].axis('off') 
        for spine in ax[digit, i].spines.values():
            spine.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# (2) Evaluate a K-Nearest-Neighbors model with k = [1,3,5,7,9] using the mini training set. Report accuracy on the dev set. For k=1, show precision, recall, and F1 for each label. Which is the most difficult digit?
#
# - KNeighborsClassifier() for fitting and predicting
# - classification_report() for producing precision, recall, F1 results

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
# Values of k to test
k_values = [1, 3, 5, 7, 9]

# Store results for later comparison
results = {}

# Training and evaluating the model for each k
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(mini_train_data, mini_train_labels)
    dev_predicted = knn.predict(dev_data)
    
    # Calculate accuracy
    accuracy = accuracy_score(dev_labels, dev_predicted)
    results[k] = {
        'accuracy': accuracy,
        'predicted_labels': dev_predicted
    }
    
    print(f'Accuracy for k={k}: {accuracy:.4f}')

# Detailed classification report for k=1
print("\nClassification report for k=1:")
print(classification_report(dev_labels, results[1]['predicted_labels']))

# Determining the most difficult digit for k=1
report = classification_report(dev_labels, results[1]['predicted_labels'], output_dict=True)
lowest_f1 = min(report[d]['f1-score'] for d in report if d.isdigit())
most_difficult_digit = [d for d in report if d.isdigit() and report[d]['f1-score'] == lowest_f1][0]
print(f"The most difficult digit to predict for k=1 is: {most_difficult_digit}")
# Out:
# Accuracy for k=1: 0.8840
# Accuracy for k=3: 0.8760
# Accuracy for k=5: 0.8820
# Accuracy for k=7: 0.8770
# Accuracy for k=9: 0.8750
#
# Classification report for k=1:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       106
#            1       0.89      0.98      0.93       118
#            2       0.90      0.79      0.84       106
#            3       0.93      0.87      0.90        97
#            4       0.91      0.85      0.88        92
#            5       0.86      0.88      0.87        88
#            6       0.92      0.92      0.92       102
#            7       0.85      0.94      0.89       102
#            8       0.83      0.77      0.80        94
#            9       0.80      0.86      0.83        95
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.89      0.88      0.88      1000
#
# ...

# %% [markdown]
# (3) Project updates! Prepare a ppt deck for class!
